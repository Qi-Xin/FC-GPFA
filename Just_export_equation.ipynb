# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt

text = "$\mathbf{z}_{r}^{a,j}$" + "\t $q(\mathbf{z}_{r}^{a,j} \mid )$" + "\t $\lambda$"

plt.figure(figsize=(3, 3), dpi=300)
plt.plot([1,2,3])
plt.text(x=0, y=2.5, s=text, fontsize=7)
plt.savefig('Figure/assist_equation.pdf')
